# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from scipy.fftpack import ifft, fft, fftfreq

# %%
import numpy as np 
import matplotlib.pyplot as pl
solecito=np.genfromtxt("./monthrg.dat")

# %%
tiempo=solecito[:,0]+((1/12)*(solecito[:,1]-1))

# %%
figure(1,figsize=(15,8))
plot(tiempo,solecito[:,3],color='blueviolet')

show()

# %% [markdown]
# #Transformada de Fourier

# %%
frec=fft(solecito[:,4])

# %%
print frec
# Out:
# [ 39066.50000000   +0.j           1216.02957910+4162.31461571j
#   -2307.68713142+1739.44760217j ...,   -290.90032546-3070.00553349j
#   -2307.68713142-1739.44760217j   1216.02957910-4162.31461571j]
